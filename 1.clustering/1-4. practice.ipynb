# %% [markdown]
# # Practice
#
# - 활요하는 것을 해보고 싶다는 요청이 있어서 실습데이터를 만들어봄
# - 해당 데이터는 캐글에서 타이타닉 예측 자료 중 일부 수정함
#
#
# - 군집화기법을 사용하여 가장 잘 분리할 수 있는 모형을 만들어보자!!

# %%
import numpy as np
import pandas as pd 
import seaborn as sns

# %%
# d = pd.read_csv('../titanic/train.csv')

# d = d.drop(['Cabin', 'Ticket', 'Name'], axis=1)
# data = d.dropna(axis=0)
# data.to_csv('titanic.csv', index=False)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
data = pd.read_csv('titanic.csv')
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   712.000000  712.000000  712.000000  712.000000  712.000000
# mean    448.589888    0.404494    2.240169   29.642093    0.514045
# std     258.683191    0.491139    0.836854   14.492933    0.930692
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     222.750000    0.000000    1.000000   20.000000    0.000000
# 50%     445.000000    0.000000    2.000000   28.000000    0.000000
# 75%     677.250000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  712.000000  712.000000
# mean     0.432584   34.567251
# std      0.854181   52.938648
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.645850
# 75%      1.000000   33.000000
# max      6.000000  512.329200

# %%
sns.pairplot(data)

# %%
sns.distplot(data['Pclass'])

# %%
sns.distplot(data['Age'])

# %%
sns.distplot(data['SibSp'])

# %%
sns.distplot(data['Parch'])

# %%
sns.distplot(data['Fare'])
